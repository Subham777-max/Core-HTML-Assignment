# %% [markdown]
# 1)Build a simple webpage that displays text as shown in the below image.
# ![Screenshot 2025-01-30 154801.png](data:image/png;base64,...)

# %%
#Ans-
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Document</title>
</head>
<body>
    <p><b>This text will be bolded</b></p>
    <p><i>This text will be italic</i></p>
    <p><ins>This text will be underlined</ins></p>
    <p><mark>This text will be highlited</mark></p>
    <p>This is normal text <sup>This will be super scripted</sup> This is normal again</p>
    <p>This is normal text <sub>This will be subscripted</sub></p>
    <p>Normal Text <small>Small Text</small></p>
    <del>This text will be deleted</del>
</body>
</html>

# %% [markdown]
# 2)Build a simple webpage that helps users navigate different web development-related websites. Note: On
# clicking the hyperlink the web pages should open in a new tab.

# %%
#Ans-
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Document</title>
</head>
<body>
    <h1>Navigate Me:</h1>
    <p>Take me to <a href="https://pwskills.com/learn/" target="_blank">PW Skills</a> to buy a course</p>
    <p>Take me to <a href="https://developer.mozilla.org/en-US/" target="_blank">MDN docs</a> to know more about web devolopment</p>
    <p>Take me to <a href="https://lab.pwskills.com/" target="_blank">PW Skills Lab</a> to practice live coding</p>
</body>
</html>

# %% [markdown]
# 3) Build a simple blog web page with 3 pages home, web development, and web design. Each page must
# contain hyperlinks to other pages in the top, a heading of the page topic and a paragraph of information.
# For the home page you can add some information about yourself.

# %%
#Ans-

#Home Page
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Home</title>
</head>
<body>
    <h1>Welcome To My Blog</h1>
    <p>Hello! I am a Computer Science student passionate about web development and design.</p>
    <p>Through this blog I will explain what is Web devolopment and Web desgine</p>

    <a href="webDevolopment.html">WebDevolopment</a>
    <br>
    <a href="webDesgine.html">WebDesgine</a>
</body>
</html>

# %%
#webDevolopment
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Web Devolopment</title>
</head>
<body>
    <h1>Web Devolopment</h1>
    <p>Web development involves building and maintaining websites. It includes frontend (HTML, CSS, JavaScript) and backend (Node.js, Python, PHP) technologies that power web applications</p>

    <a href="home.html">Home</a>
    <br>
    <a href="webDesgine.html">WebDesgine</a>
</body>
</html>

# %%
#webDesgine
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Web Desgine</title>
</head>
<body>
    <h1>Web Desgine</h1>
    <p>Web design focuses on the aesthetics and usability of a website. It involves UI/UX design, color theory, typography, and tools like Figma and Adobe XD</p>

    <a href="home.html">Home</a>
    <br>
    <a href="webDevolopment.html">WebDevolopment</a>
</body>
</html>

# %% [markdown]
# 4)Create an ordered list of HTML tags. Each list item must include the tag name and some information about
# the tag.

# %%
#Ans-
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Document</title>
</head>
<body>
    <h1>HTML Tags</h1>
    <ol>
        <li><p>P-tag:- This tag is also known as paragraph tag.This is use to write paragraphs and this a block element.</p></li>
        <li><p>Anchor-tag:- This use to add hyperlinks to the web page.This is a inline element. </p></li>
        <li>
            <p>List-tags:- There is two types of list tsgs-</p>
            <ol>
                <li><p>Ordered list(ol)</p></li>
                <li><p>Unordered list(ul)</p></li>
            </ol>
        </li>
        <li><p>B-tag:- It is used to write bold texts</p></li>
        <li><p>I-tag:- It is used to write italic texts</p></li>
        <li><p>Mark-tag:- It is used to highlite texts</p></li>
        <li><p>SUB-tag:- This is used to add subscript</p></li>
        <li><p>SUB-tag:- This is used to add superscript</p></li>
        <li><p>Image-tag:- It is used to insert image in web page</p></li>
        <li>
            <p>Table-tag:- It is used to creat a table, it has three parts-</p>
            <ol>
                <li>tr-tag:- It adds table rows</li>
                <li>th-tag:- It is table headder</li>
                <li>td-tag:- It is table data</li>
            </ol>
        </li>
    </ol>
    <p>There is so many more tags except these ten tags.</p>
</body>
</html>

# %% [markdown]
# 5)Create a description list of full stack web development tech stack, using the < dl > tag. Each term should be
# a tech stack name and each description should be a brief explanation of what the tech stack is used for.

# %%
#Ans-
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Document</title>
</head>
<body>
    <h1><ins>Components Of Full Stac Devolopment</ins></h1>
    <dl>
        <dt>HTML</dt>
        <dd>HTML stands for hyper text markup language and it used to creat the structure of a web page</dd>

        <dt>CSS</dt>
        <dd>CSS stands for cascading style sheet and it is use to desgine the web page</dd>

        <dt>Java Script</dt>
        <dd>A programming language used to add interactivity and dynamic behavior to web page</dd>

        <dt>React JS</dt>
        <dd>A Java Script library for building fast and interactive user interfaces using a component-based approach</dd>

        <dt>Node Js</dt>
        <dd>A runtime environment that allows JavaScript to be used for server-side development</dd>

        <dt>Express JS</dt>
        <dd>A lightweight Node.js web framework for building APIs and handling server-side logic</dd>

        <dt>MongoDB</dt>
        <dd>A NoSQL database that stores data in flexible JSON-like documents</dd>
    </dl>
</body>
</html>

# %% [markdown]
# 6) Create an ordered list of the full stack web development tech stack HTML, CSS, and JS. For each tech
# stack, create a table that lists the tech stack name, its primary use cases, and some key features or
# benefits.

# %%
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Document</title>
</head>
<body>
    <ol>
        <li>
            <h1>HTML</h1>
            <table border="1" cellpadding="5" cellspacing="3">
                <tr>
                    <th>Primary use case</th>
                    <th>Key Features/Benefits</th>
                </tr>
                <tr>
                    <td>Building the structure of web page</td>
                    <td>
                        <ul>
                            <li>Simple and easy to learn</li>
                            <li>Compatible with all web browser</li>
                            <li>Allows for semantic markups</li>
                        </ul>
                    </td>
                </tr>
            </table>
        </li>
        <li>
            <h1>CSS</h1>
            <table border="1" cellpadding="5" cellspacing="3">
                <tr>
                    <th>Primary use case</th>
                    <th>Key Features/Benefits</th>
                </tr>
                <tr>
                    <td>Styling and Layout of web page</td>
                    <td>
                        <ul>
                            <li>Allows for separation of content and presentation</li>
                            <li>Enables responsive desgine</li>
                            <li>Offers a wide range of styling options</li>
                        </ul>
                    </td>
                </tr>
            </table>
        </li>
        <li>
            <h1>JS</h1>
            <table border="1" cellpadding="5" cellspacing="3">
                <tr>
                    <th>Primary use case</th>
                    <th>Key Features/Benefits</th>
                </tr>
                <tr>
                    <td>Adding interactivity and dynamic behavior to web page</td>
                    <td>
                        <ul>
                            <li>Runs directly in the browser, reducing server load and improving speed.</li>
                            <li> Enables animations, real-time updates, and user interactions.</li>
                            <li>Works across all modern browsers and supports various frameworks like React and Node.js</li>
                        </ul>
                    </td>
                </tr>
            </table>
        </li>
    </ol>
</body>
</html>

# %% [markdown]
# 7)7 Build a complex nested list structure representing a multi-level table of contents. Use unordered lists
# (< ul >) and list items (< li >) with inline-block styling to create a structured layout. Apply formatting tags to
# enhance the presentation of list items.

# %%
#Ans-
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Document</title>
</head>
<body>
    <h1>Table of Content</h1>
    <ul>
        <li><ins style="color: blue;">Part 1: Introduction</ins></li>
        <li>
            <ins style="color: blue;">Part 2: Getting Started with</ins>
            <ul>
                <li><ins style="color: blue;">2.1 Installing the Software</ins></li>
                <li>
                    <ins style="color: blue;">2.2 Creating a New Project</ins>
                    <ul>
                        <li><ins style="color: blue;">2.2.1 Project Templates</ins></li>
                        <li><ins style="color: blue;">2.2.2 Customizing Settings</ins></li>
                    </ul>
                </li>
                <li>
                    <ins style="color: blue;">2.3 Exploring the Interface</ins>
                    <ul>
                        <li><ins style="color: blue;">2.3.1 Toolbar Features</ins></li>
                        <li>
                            <ins style="color: blue;">2.3.2 Panel Layout</ins>
                            <ul>
                                <li><ins style="color: blue;">2.3.2.1 Docking Panels</ins></li>
                                <li><ins style="color: blue;">2.3.2.2 Tabbed Interface</ins></li>
                            </ul>
                        </li>
                    </ul>
                </li>
            </ul>
        </li>
        <li>
            <ins style="color: blue;">Part 3: Advanced Topics</ins>
            <ul>
                <li>
                    <ins style="color: blue;">3.1 Working with Plugins</ins>
                </li>
                <ul>
                    <li><ins style="color: blue;">3.1.1 Installing Plugins</ins></li>
                    <li><ins style="color: blue;">3.1.2 Plugin Configuration</ins></li>
                </ul>
                <li>
                    <ins style="color: blue;">3.2 Customizing the UI</ins>
                    <ul>
                        <li><ins style="color: blue;">3.2.1 Changing Themes</ins></li>
                        <li><ins style="color: blue;">3.2.2 Configuring Shortcuts</ins></li>
                    </ul>
                    <li>
                        <ins style="color: blue;">3.3 Optimizing Performence</ins>
                        <ul>
                            <li><ins style="color: blue;">3.3.1 Caching Strategies</ins></li>
                            <li><ins style="color: blue;">3.3.2 Resourse Minification</ins></li>
                        </ul>
                    </li>
                </li>
            </ul>
        </li>
        <li><ins style="color: blue;">Part 4: Conclusion</ins></li>
    </ul>
</body>
</html>

# %% [markdown]
# 8)5 Create a table to display a conference schedule. Each row corresponds to a time slot, and each column
# corresponds to a room. Some time slots might have multiple sessions running simultaneously in different
# rooms. Utilize rowspan and colspan attributes as necessary to accommodate this complex schedule.
# (use table attribute “cellpadding”  to give extra padding in each table cell ).

# %%
#Ans-
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Document</title>
</head>
<body>
    <h1>Conference Schedule</h1>
    <table border="1" cellpadding="15" cellspacing="3">
        <tr>
            <th>Time</th>
            <th>Room 1</th>
            <th>Room 2</th>
            <th>Room 3</th>
            <th>Room 4</th>
        </tr>
        <tr>
            <td rowspan="3">9:00 AM - 10:00 AM</td>
            <td rowspan="2">Keynote</td>
            <td>Session A</td>
            <td>Session B</td>
            <td rowspan="3">Session C</td>
        </tr>
        <tr>
            <td>Session D</td>
            <td>Session E</td>
        </tr>
        <tr>
            <td>10:30 AM - 11:30 AM</td>
            <td colspan="2">Session F</td>
        </tr>
        <tr>
            <td>12:00 PM - 1:00 PM</td>
            <td colspan="4">Lunch Break</td>
        </tr>
        <tr>
            <td rowspan="2">1:00 PM - 2:00 PM</td>
            <td>Session G</td>
            <td rowspan="2">Session H</td>
            <td>Session I</td>
            <td>Session J</td>
        </tr>
        <tr>
            <td>Session K</td>
            <td>Session L</td>
            <td>Session M</td>
        </tr>
    </table>
</body>
</html>
